# %% [markdown]
# <a href="https://colab.research.google.com/github/uneliiv/team_19/blob/main/Python_Tasks_13_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Create a bar chart that shows the count of transactions for each unique value in the 'Gender' column (including NaN values). - **easy**

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/transaction_dataset.csv")



gender_counts = df['Gender'].value_counts(dropna=False)



gender_counts.plot(kind='bar', color=['pink', 'skyblue', 'grey'])
plt.title('Transaction Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count of Transactions')

plt.show()

# %% [markdown]
# Task 2: Create a horizontal bar chart that shows the top 5 most frequent names in the DataFrame, based on the 'name' column. (First, create a grouped DataFrame (name_df), then filter it using iloc, and finally create the visualization.) -**medium**

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/transaction_dataset.csv")
name_df = df['Name'].value_counts().reset_index()
name_df.columns = ['Name', 'Count']


top_5_names = name_df.iloc[:5]

plt.figure(figsize=(10, 6))
top_5_names.plot(kind='barh', x='Name', y='Count', legend=False, color='slateblue')
plt.title('Top 5 Most Frequent Names')
plt.xlabel('Count')
plt.ylabel('Name')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Task 3: Create a filtered DataFrame that includes Category == 'Clothing' and Gender == 'M'. How many rows are there in this filtered DataFrame? Format the result as follows: The filtered DataFrame has XXXX rows. - **hard**

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/transaction_dataset.csv")

filtered_df = df[(df['Category'] == 'Clothing') & (df['Gender'] == 'M')]

# Count the number of rows in the filtered DataFrame
filtered_row_count = filtered_df.shape[0]

print(f'The filtered DataFrame has {filtered_row_count} rows.')
# Out:
# The filtered DataFrame has 3738 rows.
